# %% [markdown]
# # Train Hand Digit Model on Google Colab
# Follow these steps to train your model using Colab's free GPU:
# 1. Go to **Runtime > Change runtime type** and select **T4 GPU**.
# 2. Upload your entire `Hand` project folder (including `digit_model_training` and `handDigitDataset`) to your Google Drive.
# 3. Run the cells below.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# TODO: Change this path if you uploaded the 'Hand' folder to a different location in your Google Drive
import os
os.chdir('/content/drive/MyDrive/Hand/digit_model_training')
# !pwd

# %%
# Install any missing dependencies required by your code
# !pip install -r requirements.txt

# %%
# Start the training pipeline!
# !python main.py
